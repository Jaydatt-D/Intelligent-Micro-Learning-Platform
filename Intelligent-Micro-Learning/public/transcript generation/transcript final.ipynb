# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-hqb3jdgi
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-hqb3jdgi
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
# !whisper "PHP.mp4" --model medium.en
# !whisper "PostGREsql.mp4" --model medium.en
# !whisper "Django.mp4" --model medium.en
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:12<00:00, 124MiB/s]
# [00:00.000 --> 00:05.000]  Hey there, this is Kamal, and in this video, we're gonna learn the basics of PHP.
# [00:05.000 --> 00:07.000]  So, let's get this started.
# [00:07.000 --> 00:10.000]  So, before going further, let me clarify a few things.
# [00:10.000 --> 00:15.000]  I'm assuming that you only have a basic idea or some of the concepts of programming languages,
# [00:15.000 --> 00:19.000]  like variables, functions, loops, and conditional statements.
# [00:19.000 --> 00:24.000]  So, if you have a basic idea of what these terms mean, then this video will be really easy for you.
# [00:24.000 --> 00:29.000]  But if you have no idea what I'm talking about, then you might have a bit difficulty to understand what's going on,
# [00:29.000 --> 00:32.000]  as I'm trying to explain all these things in a very short time.
# ...

# %%
# !whisper "PostGREsql.mp4" --model medium.en
# !whisper "Django.mp4" --model medium.en
# Out:
# [00:00.000 --> 00:05.000]  So you want to learn Postgres, huh? Well, I know a thing or two about Postgres.
# [00:05.000 --> 00:11.000]  In fact, I would say that learning Postgres and SQL has been one of the most beneficial skills
# [00:11.000 --> 00:15.000]  I've learned throughout my entire career. Not only has it been helpful on the job,
# [00:15.000 --> 00:21.000]  it's also been a really impressive skill to be able to flex in interviews with potential employers,
# [00:21.000 --> 00:27.000]  and I've landed multiple contract jobs just because I know Postgres well enough
# [00:27.000 --> 00:30.000]  to be able to do things that other developers simply can't.
# [00:30.000 --> 00:37.000]  Today, in this video, I'm going to give you some initial skills to help you on your journey to Postgres Mastery.
# [00:37.000 --> 00:41.000]  We're just going to be talking about a lot of the basics. Perhaps in future videos,
# ...
